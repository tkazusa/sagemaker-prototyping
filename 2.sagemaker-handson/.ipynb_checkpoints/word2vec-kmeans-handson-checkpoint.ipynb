# %% [markdown]
# ## はじめに
# 本ハンズオンではSageMakerの組み込みアルゴリズムを活用した機械学習を体験頂きます。学習に使うデータをAmazon S3のバケットへアップロードし、組み込みアルゴリズムとSageMakerの学習用インスタンスを使ってモデルを学習、学習されたモデルを推論インスタンスへデプロイする流れをご確認下さい。
#
# 今回はテキストデータについて類似の単語群を探すというタスクを下記の手順で行います。
# - wikipedia由来のデータ用いてWord2Vecモデルを学習
# - Word2Vecモデルが適切に学習されているかを確認
#     - テキストデータをWrod2Vecで100次元のベクトル表現へ変換
#     - 100次元のベクトルをt-SNEを用いて2次元のベクトルへ次元圧縮
#     - 2次元データを散布図で可視化し定性的に評価
# - 100次元データをK-Meansアルゴリズムを用いてクラスタリングし、似た表現のグループを作成
# - 未知のデータをWord2Vecで100次元ベクトル化した上で、上述のどのグループに所属するかを計算
#
# 今後のプロトタイピングを実施するに辺り、本ハンズオンをとおしてご確認を頂きたい概念は下記です。
# - SageMakerの組み込みアルゴリズムを用いた機械学習の実施
# - テキストデータをベクトルへ変換するとはどういうことか
# - 次元圧縮するとはどういうことか
# - クラスタリングとは何か
#
# 逆に、現時点で時間をかけて頂かなくて良い点は下記になります。
# - 機械学習アルゴリズムそのもの(今回で言えばWord2Vec、t-SNE、K-Meansなど自体）
# - Pythonライブラリのそれぞれの文法や詳細(numpy, pandas, scikit-learn、SageMakerなど)
# - 今回はほとんど行っていない自然言語処理におけるデータの前処理(ノイズの除去や単語の正規化、ストップワードの除去など)

# %% [markdown]
# ### データの準備
# 今回はWikipediaから抽出した文章に対してクリーニングなどの処理をした後の[ja.text8](https://github.com/Hironsan/ja.text8)という100MB程度のデータ(コーパス)を活用します。

# %%
# データのダウンロードと解凍
# !wget https://s3-ap-northeast-1.amazonaws.com/dev.tech-sketch.jp/chakki/public/ja.text8.zip
# !unzip -o ja.text8.zip
# Out:
# --2019-08-17 22:50:57--  https://s3-ap-northeast-1.amazonaws.com/dev.tech-sketch.jp/chakki/public/ja.text8.zip
# Resolving s3-ap-northeast-1.amazonaws.com (s3-ap-northeast-1.amazonaws.com)... 52.219.4.134
# Connecting to s3-ap-northeast-1.amazonaws.com (s3-ap-northeast-1.amazonaws.com)|52.219.4.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33905114 (32M) [application/zip]
# Saving to: ‘ja.text8.zip’
#
# ja.text8.zip        100%[===================>]  32.33M  9.10MB/s    in 4.5s
#
# 2019-08-17 22:51:03 (7.21 MB/s) - ‘ja.text8.zip’ saved [33905114/33905114]
#
# Archive:  ja.text8.zip
#   inflating: ja.text8

# %% [markdown]
# データを読み込み、中身を確認します。総単語数、ユニークな単語数、文書を見ます。

# %%
import sagemaker
from sagemaker import get_execution_role
import boto3
import json

sess = sagemaker.Session()
role = get_execution_role()


# ファイルの読み込み
with open("ja.text8") as f:
    words = f.read().split()
    
print("総単語数:{}".format(len(words)))
print("ユニークな単語数：{}".format(len(set(words))))
# Out:
# 総単語数:16900026
# ユニークな単語数：290811

# %%
# どのような文章か先頭300単語を表示
"".join(words[:300])
# Out:
# 'ちょん掛け（ちょんがけ、丁斧掛け・手斧掛けとも表記）とは、相撲の決まり手のひとつである。自分の右（左）足の踵を相手の右（左）足の踵に掛け、後方に捻って倒す技。手斧（ちょうな）をかける仕草に似ていることから、ちょうなが訛ってちょん掛けとなったといわれる。柔道の小内刈とほぼ同じ動きを見せる技である。1944年1月場所6日目、36連勝中の横綱双葉山に、枩ノ里が決め、金星を挙げている。最近では2014年11月場所7日目に常幸龍が照ノ富士に、2012年5月場所5日目に朝赤龍が若の里にこの技で勝利しているほか、十両では2014年1月場所12日目に天鎧鵬が双大竜に、2013年5月場所2日目に鬼嵐が丹蔵に、それぞれこの技で勝利している。幕下以下では旭大星が得意としており、10回以上この技を決めている。甲越同盟（こうえつどうめい）は、天正7年（1579年）に甲斐の戦国大名武田勝頼と越後の戦国大名上杉景勝との間で成立した同盟。3年後の天正10年（1582年）に起こった甲州'

# %% [markdown]
# # データのアップロード
# SageMakerの学習インスタンスが利用できるよう、データをS3のバケットへアップロードします。

# %%
# アップロード先を指定
prefix = 'sagemaker/DEMO-blazingtext-text8' 
train_channel = prefix + '/train'

# S3へアップロード
bucket = sess.default_bucket() # Replace with your own bucket name if needed
sess.upload_data(path='ja.text8', bucket=bucket, key_prefix=train_channel)

# アップロード先のパス
s3_train_data = 's3://{}/{}'.format(bucket, train_channel)
s3_output_location = 's3://{}/{}/output'.format(bucket, prefix)

# %% [markdown]
# # Word2Vecアルゴリズムの学習
# 今回はSageMakerのWord2Vecの組み込みアルゴリズムであるBlazingTextを活用します。

# %%
region_name = boto3.Session().region_name
container = sagemaker.amazon.amazon_estimator.get_image_uri(region_name, "blazingtext", "latest")


# どのような学習を行うかの設定
bt_model = sagemaker.estimator.Estimator(container,
                                         role, 
                                         train_instance_count=2, 
                                         train_instance_type='ml.c4.2xlarge',
                                         train_volume_size = 5,
                                         train_max_run = 360000,
                                         input_mode= 'File',
                                         output_path=s3_output_location,
                                         sagemaker_session=sess)


# Word2Vecアルゴリズムのハイパラ設定
bt_model.set_hyperparameters(mode="batch_skipgram",
                             epochs=5,
                             min_count=5,
                             sampling_threshold=0.0001,
                             learning_rate=0.05,
                             window_size=5,
                             vector_dim=100,
                             negative_samples=5,
                             batch_size=11, #  = (2*window_size + 1) (Preferred. Used only if mode is batch_skipgram)
                             evaluation=True,# Perform similarity evaluation on WS-353 dataset at the end of training
                             subwords=False) # Subword embedding learning is not supported by batch_skipgram

# 学習データの指定
train_data = sagemaker.session.s3_input(s3_train_data,
                                        distribution='FullyReplicated',
                                        content_type='text/plain',
                                        s3_data_type='S3Prefix')
data_channels = {'train': train_data}


# 学習の開始
bt_model.fit(inputs=data_channels, logs=True)
# Out:
# 2019-08-17 22:51:11 Starting - Starting the training job...
# 2019-08-17 22:51:13 Starting - Launching requested ML instances......
# 2019-08-17 22:52:14 Starting - Preparing the instances for training...
# 2019-08-17 22:53:07 Downloading - Downloading input data...
# 2019-08-17 22:53:36 Training - Training image download completed. Training in progress.
# Arguments: train
# Arguments: train
# Found 10.2.176.30 for host algo-1
# Found 10.2.128.108 for host algo-2
# Found 10.2.176.30 for host algo-1
# Found 10.2.128.108 for host algo-2
# [08/17/2019 22:53:49 WARNING 140636602758976] Loggers have already been setup.
# [08/17/2019 22:53:49 WARNING 140636602758976] Loggers have already been setup.
# [08/17/2019 22:53:49 INFO 140636602758976] nvidia-smi took: 0.0252590179443 secs to identify 0 gpus
# [08/17/2019 22:53:49 INFO 140636602758976] Running distributed CPU BlazingText training using batch_skipgram on 2 hosts.
# [08/17/2019 22:53:49 INFO 140636602758976] Number of hosts: 2, master IP address: 10.2.176.30, host IP address: 10.2.176.30.
# [08/17/2019 22:53:49 INFO 140636602758976] HTTP server started....
# [08/17/2019 22:53:49 INFO 140636602758976] Processing /opt/ml/input/data/train/ja.text8 . File size: 95 MB
# Warning: Permanently added 'algo-2,10.2.128.108' (ECDSA) to the list of known hosts.#015
# [08/17/2019 22:53:50 WARNING 139965695895360] Loggers have already been setup.
# [08/17/2019 22:53:50 WARNING 139965695895360] Loggers have already been setup.
# [08/17/2019 22:53:50 INFO 139965695895360] nvidia-smi took: 0.025171995163 secs to identify 0 gpus
# [08/17/2019 22:53:50 INFO 139965695895360] Running distributed CPU BlazingText training using batch_skipgram on 2 hosts.
# [08/17/2019 22:53:50 INFO 139965695895360] Number of hosts: 2, master IP address: 10.2.176.30, host IP address: 10.2.128.108.
# processor name: algo-2, number of processors: 2, rank: 1
# processor name: algo-1, number of processors: 2, rank: 0
# Read 10M words
# Read 16M words
# Number of words:  75207
# Alpha: 0.0488  Progress: 2.24%  Million Words/sec: 4.55
# Alpha: 0.0462  Progress: 7.48%  Million Words/sec: 5.01
# Alpha: 0.0436  Progress: 12.68%  Million Words/sec: 5.09
# Alpha: 0.0410  Progress: 17.90%  Million Words/sec: 5.15
# Alpha: 0.0383  Progress: 23.13%  Million Words/sec: 5.14
# Alpha: 0.0357  Progress: 28.39%  Million Words/sec: 5.15
# Alpha: 0.0331  Progress: 33.52%  Million Words/sec: 5.15
# Alpha: 0.0304  Progress: 38.75%  Million Words/sec: 5.17
# Alpha: 0.0278  Progress: 43.97%  Million Words/sec: 5.14
# Alpha: 0.0252  Progress: 49.18%  Million Words/sec: 5.15
# Alpha: 0.0226  Progress: 54.37%  Million Words/sec: 5.16
# Alpha: 0.0199  Progress: 59.61%  Million Words/sec: 5.17
# Alpha: 0.0174  Progress: 64.76%  Million Words/sec: 5.15
# Alpha: 0.0147  Progress: 70.05%  Million Words/sec: 5.16
# Alpha: 0.0121  Progress: 75.20%  Million Words/sec: 5.16
# Alpha: 0.0094  Progress: 80.50%  Million Words/sec: 5.17
# Alpha: 0.0068  Progress: 85.76%  Million Words/sec: 5.15
# Alpha: 0.0042  Progress: 90.98%  Million Words/sec: 5.16
# Alpha: 0.0016  Progress: 96.20%  Million Words/sec: 5.16
# Alpha: 0.0000  Progress: 100.00%  Million Words/sec: 5.00
#
# Training finished!
# Average throughput in Million words/sec: 5.00
# Total training time in seconds: 16.92
# Evaluating word embeddings....
# Vectors read from: /opt/ml/model/vectors.txt
# {
#     "EN-WS-353-ALL.txt": {
#         "not_found": 209,
#         "spearmans_rho": 0.2462945523019463,
#         "total_pairs": 353
#     },
#     "EN-WS-353-REL.txt": {
#         "not_found": 152,
#         "spearmans_rho": 0.10925643136622379,
#         "total_pairs": 252
#     },
#     "EN-WS-353-SIM.txt": {
#         "not_found": 121,
#         "spearmans_rho": 0.3816272116981527,
#         "total_pairs": 203
#     },
#     "mean_rho": 0.2457260651221076
# }
# [08/17/2019 22:54:18 INFO 140636602758976] #mean_rho: 0.2457260651221076
#
# 2019-08-17 22:55:29 Uploading - Uploading generated training model[08/17/2019 22:55:28 INFO 139965695895360] Master host is not alive. Training might have finished. Shutting down.... Check the logs for algo-1 machine.
#
# 2019-08-17 22:55:56 Completed - Training job completed
# Billable seconds: 340

# %% [markdown]
# # Word2Vecを使って単語のベクトル表現を得る
# まずは学習されたWord2Vecを推論エンドポイントへデプロイして、推論(単語のベクトル表現化)ができる状態にします。

# %%
bt_endpoint = bt_model.deploy(initial_instance_count = 1,instance_type = 'ml.m4.xlarge')
# Out:
# Using already existing model: blazingtext-2019-08-17-22-51-11-290
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-11-c3c285a68955> in <module>()
# ----> 1 bt_endpoint = bt_model.deploy(initial_instance_count = 1,instance_type = 'ml.m4.xlarge')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, use_compiled_model, update_endpoint, wait, model_name, **kwargs)
#     513             update_endpoint=update_endpoint,
#     514             tags=self.tags,
# --> 515             wait=wait,
#     516         )
#     517
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/model.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, update_endpoint, tags, kms_key, wait)
#     448         else:
#     449             self.sagemaker_session.endpoint_from_production_variants(
# --> 450                 self.endpoint_name, [production_variant], tags, kms_key, wait
#     451             )
#     452
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in endpoint_from_production_variants(self, name, production_variants, tags, kms_key, wait)
#    1286
#    1287             self.sagemaker_client.create_endpoint_config(**config_options)
# -> 1288         return self.create_endpoint(endpoint_name=name, config_name=name, tags=tags, wait=wait)
#    1289
#    1290     def expand_role(self, role):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in create_endpoint(self, endpoint_name, config_name, tags, wait)
#     921
#     922         self.sagemaker_client.create_endpoint(
# --> 923             EndpointName=endpoint_name, EndpointConfigName=config_name, Tags=tags
#     924         )
#     925         if wait:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     659             error_code = parsed_response.get("Error", {}).get("Code")
#     660             error_class = self.exceptions.from_code(error_code)
# --> 661             raise error_class(parsed_response, operation_name)
#     662         else:
#     663             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateEndpoint operation: Cannot create already existing endpoint "arn:aws:sagemaker:us-east-1:815969174475:endpoint/blazingtext-2019-08-17-22-51-11-290".

# %% [markdown]
# 準備ができたので単語をベクトルに変換してみます。

# %%
# 自転車や女性という単語を推論するようリクエストを作成
words = ["自動車", "女性"]
request = json.dumps({"instances" : words})

# リクエストを推論エンドポイントへ投げ、レスポンスを得る
response = bt_endpoint.predict(request)

# レスポンスの中身を確認
vecs = json.loads(response)
print(vecs[0])
# Out:
# {'vector': [0.20162972807884216, 0.4225836992263794, -0.4392703175544739, 0.07255113869905472, 0.3022313117980957, -0.09452702105045319, 0.08236310631036758, -0.5880864858627319, 0.27514123916625977, 0.071651391685009, 0.18807217478752136, -0.3275327980518341, -0.5597971677780151, -0.06089580059051514, 0.03364931046962738, 0.38424256443977356, -0.28624293208122253, 0.25423669815063477, 0.011474644765257835, -0.14905059337615967, -0.8561735153198242, -0.5004375576972961, 0.084535151720047, 0.061208851635456085, -0.3617333471775055, 0.2536694407463074, 0.6511583924293518, 0.2754310965538025, 0.036474667489528656, -0.5177932381629944, 0.030990231782197952, -0.15393903851509094, 0.14912228286266327, -0.08791393041610718, -0.6146922707557678, 0.2113725244998932, -0.7637321949005127, 0.08207248151302338, 0.012919342145323753, -0.4285295009613037, -0.3663647770881653, -0.029295463114976883, 0.3679848909378052, 0.09060142934322357, -0.15764935314655304, -0.2783055603504181, 0.28491875529289246, -0.13009437918663025, -0.28981971740722656, 0.025638241320848465, -0.6584784984588623, -0.45873475074768066, 0.21853075921535492, 0.4068477749824524, 0.0675743892788887, -0.1446891725063324, -0.375627338886261, -0.2137264609336853, -0.6705218553543091, 0.9219855666160583, 0.22806695103645325, 0.18503305315971375, 0.33720242977142334, 0.26498711109161377, 0.6315835118293762, -0.4396407902240753, 0.5014269351959229, -0.011597082950174809, -0.10424449294805527, -0.6362754106521606, -0.14060133695602417, -0.22945746779441833, -0.13818076252937317, -0.5125347375869751, -0.06196201592683792, 0.026644572615623474, -0.010768817737698555, 0.06052422150969505, 0.04660213738679886, -0.4790325164794922, 0.4476150870323181, -0.20148687064647675, 0.5751702785491943, -0.1111348569393158, 0.03194507956504822, 0.4728890657424927, 0.08095460385084152, -0.3169526159763336, 0.05639069527387619, -0.2566424012184143, 0.3515309691429138, -0.5459223985671997, 0.29212409257888794, -0.2402781844139099, -0.3146863281726837, -0.45561668276786804, -0.43326687812805176, -0.32496994733810425, 0.251872181892395, 0.2373146414756775], 'word': '自動車'}

# %%
print(vecs[1])
# Out:
# {'vector': [0.5065871477127075, 0.3459603488445282, 0.17983627319335938, 0.008376160636544228, 0.41055744886398315, 0.4392279386520386, -0.4528929591178894, -0.08632010966539383, 0.5014986991882324, 0.0523848757147789, 0.23467083275318146, -0.09289614111185074, 0.28049516677856445, 0.36204102635383606, -0.12990781664848328, 0.14729154109954834, -0.15884146094322205, -0.5502028465270996, -0.19847334921360016, 0.15144798159599304, 0.023077987134456635, 0.41329777240753174, -0.2341422587633133, -0.1465262770652771, -0.005758452229201794, 0.3675426244735718, 0.44021284580230713, -0.5229554176330566, 0.1719997227191925, 0.6788625717163086, 0.5540049076080322, -0.2845633625984192, -0.1901353895664215, 0.1008237898349762, -0.4120977520942688, 0.13650250434875488, -0.5500501394271851, 0.21277771890163422, -0.038838259875774384, 0.08217628300189972, -0.10043397545814514, 0.12262915074825287, -0.09204130619764328, -0.12696409225463867, 0.6061298847198486, 0.09904277324676514, -0.049218639731407166, 0.03364582359790802, 0.25298693776130676, 0.233080193400383, -0.21409407258033752, -0.6303817629814148, 0.4122524857521057, -0.34940987825393677, -0.04893525689840317, -0.48860329389572144, -0.5981857776641846, -0.15938693284988403, -0.2419968545436859, 0.04575777053833008, 0.22525635361671448, -0.3207288384437561, 0.2899836003780365, -0.22998248040676117, -0.37363892793655396, -0.02383415773510933, -0.32206183671951294, 0.04255307465791702, -0.4734013080596924, -0.2883623540401459, 0.28407931327819824, -0.27899712324142456, 0.010439340956509113, 0.10011205077171326, -0.547977089881897, 0.23092645406723022, 0.1531009078025818, 0.07903774827718735, -0.11337126791477203, 0.05052477866411209, 0.11615554988384247, -0.17494428157806396, 0.2982369065284729, -0.28434109687805176, 0.33408868312835693, -0.27446913719177246, 0.13886775076389313, 0.43755054473876953, 0.10308535397052765, 0.08577480912208557, 0.27073293924331665, -0.16423608362674713, 0.13182510435581207, 0.28653305768966675, 0.010132940486073494, -0.4843859374523163, -0.322676420211792, 0.5119503736495972, -0.2285670042037964, 0.25502854585647583], 'word': '女性'}

# %% [markdown]
# # Word2Vecの評価
# ja.text8で学習したモデルが適切に単語をベクトル化できているか確認するために、ja.text8の単語群のベクトル表現(100次元ベクトル)を入手し、t-SNEアルゴリズムで2次元のベクトル表現まで次元圧縮を行った上で、散布図を描いて可視化します。

# %%
s3 = boto3.resource('s3')
key = bt_model.model_data[bt_model.model_data.find("/", 5)+1:]
s3.Bucket(bucket).download_file(key, 'model.tar.gz')

# %% [markdown]
# ダウンロードしてきた学習済モデルのベクトル表現を解凍します。`vector.txt`がベクトル表現です。

# %%
# !tar -xvzf model.tar.gz
# Out:
# vectors.txt
# vectors.bin
# eval.json

# %% [markdown]
# ベクトル表現はデータは頻度での降順で保存されているため上位400データを可視化対象とします。

# %%
import numpy as np
from sklearn.manifold import TSNE
from sklearn.preprocessing import normalize

# 使用するデータ数を400と指定
num_points = 400

# 可視化しやすいよう前処理を行います。
first_line = True
index_to_word = []
with open("vectors.txt","r") as f:
    for line_num, line in enumerate(f):
        if first_line:
            dim = int(line.strip().split()[1])
            word_vecs = np.zeros((num_points, dim), dtype=float)
            first_line = False
            continue
        line = line.strip()
        word = line.split()[0]
        vec = word_vecs[line_num-1]
        for index, vec_val in enumerate(line.split()[1:]):
            vec[index] = float(vec_val)
        index_to_word.append(word)
        if line_num >= num_points:
            break
word_vecs = normalize(word_vecs, copy=False, return_norm=False)

# t-SNEアルゴリズムのハイパラ設定
tsne = TSNE(perplexity=40, n_components=2, init='pca', n_iter=10000)
# 100次元ベクトルから2次元ベクトルへ変換
two_d_embeddings = tsne.fit_transform(word_vecs[:num_points])
labels = index_to_word[:num_points]

# %% [markdown]
# 可視化のための準備として日本語フォントをダウンロードします。

# %%
# !sudo yum install -y ipa-gothic-fonts
# Out:
# Loaded plugins: dkms-build-requires, priorities, update-motd, upgrade-helper
# amzn-main                                                | 2.1 kB     00:00
# amzn-updates                                             | 2.5 kB     00:00
# libnvidia-container/x86_64/signature                     |  488 B     00:00
# libnvidia-container/x86_64/signature                     | 2.0 kB     00:00 !!!
# nvidia-container-runtime/x86_64/signature                |  488 B     00:00
# nvidia-container-runtime/x86_64/signature                | 2.0 kB     00:00 !!!
# nvidia-docker/x86_64/signature                           |  488 B     00:00
# nvidia-docker/x86_64/signature                           | 2.0 kB     00:00 !!!
# Package ipa-gothic-fonts-003.02-4.2.2.amzn1.noarch already installed and latest version
# Nothing to do

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib as mpl
 
mpl.font_manager._rebuild() #キャッシュの削除
plt.rcParams['font.family'] = 'IPAGothic' # インストールしたフォントを指定


def plot(embeddings, labels):
    plt.figure(figsize=(20,20))
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        plt.scatter(x, y)
        plt.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    plt.savefig('image.png')
    plt.show()

plot(two_d_embeddings, labels)

# %% [markdown]
# # 単語のクラスタリング
# ベクトル化された単語群をK-Meansアルゴリズムを使ってクラスタリングしグループを作ります。K-Meansに関してもSageMakerの組み込みアルゴリズムを使います。
# Word2Vecの時と同様にS3バケットへデータ(100次元ベクトル表現)をアップロードし、モデルを学習、推論エンドポイントへモデルをデプロイした上でモデル評価を行います。

# %%
from sagemaker import KMeans

# K-Meansアルゴリズムに学習できる形式へデータタイプを変換
word_vecs32 = word_vecs.astype('float32')

# アップロード先のパス
data_location = 's3://{}/kmeans_highlevel_example/data'.format(bucket)
output_location = 's3://{}/kmeans_example/output'.format(bucket)

# K-Meansアルゴリズムの設定
kmeans = KMeans(role=role,
                train_instance_count=2,
                train_instance_type='ml.c4.xlarge',
                output_path=output_location,
                k=10,
                data_location=data_location)

# 組み込みアルゴリズム用のデータ形式へ変換してS3へアップロード
inputs = kmeans.record_set(word_vecs32)

# 学習の開始
kmeans.fit(inputs)
# Out:
# 2019-08-17 23:35:54 Starting - Starting the training job...
# 2019-08-17 23:35:56 Starting - Launching requested ML instances......
# 2019-08-17 23:36:59 Starting - Preparing the instances for training......
# 2019-08-17 23:38:17 Downloading - Downloading input data...
# 2019-08-17 23:38:52 Training - Training image download completed. Training in progress..
# Docker entrypoint called with argument(s): train
# [08/17/2019 23:38:53 INFO 139887317694272] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'_enable_profiler': u'false', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [08/17/2019 23:38:53 INFO 139887317694272] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'100', u'k': u'10', u'force_dense': u'True'}
# [08/17/2019 23:38:53 INFO 139887317694272] Final configuration: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'100', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'10', u'_num_slices': u'1'}
# [08/17/2019 23:38:53 WARNING 139887317694272] Loggers have already been setup.
# [08/17/2019 23:38:53 INFO 139887317694272] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/2a1ff412-badd-4db5-9a29-adc05cd79c65', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.158.204', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2019-08-17-23-35-54-810', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-179-178.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/80b63d92-22c2-4ffe-b2e9-165aac3e0f39', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:815969174475:training-job/kmeans-2019-08-17-23-35-54-810', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 1 is a worker.
# [08/17/2019 23:38:53 INFO 139887317694272] Using default worker.
# [08/17/2019 23:38:53 INFO 139887317694272] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [08/17/2019 23:38:53 INFO 139887317694272] Create Store: dist_async
# [08/17/2019 23:38:55 INFO 139887317694272] nvidia-smi took: 0.0251798629761 secs to identify 0 gpus
# [08/17/2019 23:38:55 INFO 139887317694272] Number of GPUs being used: 0
# [08/17/2019 23:38:55 INFO 139887317694272] Setting up with params: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'100', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'10', u'_num_slices': u'1'}
# [08/17/2019 23:38:55 INFO 139887317694272] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [08/17/2019 23:38:55 INFO 139887317694272] Number of GPUs being used: 0
# [08/17/2019 23:38:55 INFO 139887317694272] number of center slices 1
# [08/17/2019 23:38:55 WARNING 139887317694272] Batch size 5000 is bigger than the first batch data. Effective batch size used to initialize is 200
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Max Records Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1566085135.819806, "Dimensions": {"Host": "algo-2", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1566085135.819749}
#
# [2019-08-17 23:38:55.820] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 45, "num_examples": 1, "num_bytes": 85600}
# [2019-08-17 23:38:55.870] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 49, "num_examples": 1, "num_bytes": 85600}
# [08/17/2019 23:38:55 INFO 139887317694272] processed a total of 200 examples
# [08/17/2019 23:38:55 INFO 139887317694272] #progress_metric: host=algo-2, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Total Batches Seen": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Total Records Seen": {"count": 1, "max": 400, "sum": 400.0, "min": 400}, "Max Records Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1566085135.871189, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1566085135.82018}
#
# [08/17/2019 23:38:55 INFO 139887317694272] #throughput_metric: host=algo-2, train throughput=3905.42007691 records/second
# [08/17/2019 23:38:55 INFO 139887317694272] shrinking 100 centers into 10
# [08/17/2019 23:38:55 INFO 139887317694272] local kmeans attempt #0. Current mean square distance 0.295574
# [08/17/2019 23:38:55 INFO 139887317694272] local kmeans attempt #1. Current mean square distance 0.316973
# [08/17/2019 23:38:55 INFO 139887317694272] local kmeans attempt #2. Current mean square distance 0.307190
# [08/17/2019 23:38:55 INFO 139887317694272] local kmeans attempt #3. Current mean square distance 0.296369
# [08/17/2019 23:38:56 INFO 139887317694272] local kmeans attempt #4. Current mean square distance 0.303521
# Docker entrypoint called with argument(s): train
# [08/17/2019 23:38:54 INFO 140385467369280] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'_enable_profiler': u'false', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [08/17/2019 23:38:54 INFO 140385467369280] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'100', u'k': u'10', u'force_dense': u'True'}
# [08/17/2019 23:38:54 INFO 140385467369280] Final configuration: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'100', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'10', u'_num_slices': u'1'}
# [08/17/2019 23:38:54 WARNING 140385467369280] Loggers have already been setup.
# [08/17/2019 23:38:54 INFO 140385467369280] Launching parameter server for role scheduler
# [08/17/2019 23:38:54 INFO 140385467369280] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/7e3d401d-a433-40df-9a5b-327a3350e997', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2019-08-17-23-35-54-810', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-158-204.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/7b2146c4-4ade-4b6b-8efa-b289b73054e3', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:815969174475:training-job/kmeans-2019-08-17-23-35-54-810', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [08/17/2019 23:38:54 INFO 140385467369280] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/7e3d401d-a433-40df-9a5b-327a3350e997', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.158.204', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2019-08-17-23-35-54-810', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-158-204.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/7b2146c4-4ade-4b6b-8efa-b289b73054e3', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:815969174475:training-job/kmeans-2019-08-17-23-35-54-810', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [08/17/2019 23:38:54 INFO 140385467369280] Launching parameter server for role server
# [08/17/2019 23:38:54 INFO 140385467369280] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/7e3d401d-a433-40df-9a5b-327a3350e997', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2019-08-17-23-35-54-810', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-158-204.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/7b2146c4-4ade-4b6b-8efa-b289b73054e3', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:815969174475:training-job/kmeans-2019-08-17-23-35-54-810', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [08/17/2019 23:38:54 INFO 140385467369280] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/7e3d401d-a433-40df-9a5b-327a3350e997', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.158.204', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2019-08-17-23-35-54-810', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-158-204.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/7b2146c4-4ade-4b6b-8efa-b289b73054e3', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:815969174475:training-job/kmeans-2019-08-17-23-35-54-810', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [08/17/2019 23:38:54 INFO 140385467369280] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/7e3d401d-a433-40df-9a5b-327a3350e997', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.158.204', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2019-08-17-23-35-54-810', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-158-204.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/7b2146c4-4ade-4b6b-8efa-b289b73054e3', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:815969174475:training-job/kmeans-2019-08-17-23-35-54-810', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 61 is a shell:scheduler.
# Process 70 is a shell:server.
# Process 1 is a worker.
# [08/17/2019 23:38:54 INFO 140385467369280] Using default worker.
# [08/17/2019 23:38:54 INFO 140385467369280] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [08/17/2019 23:38:54 INFO 140385467369280] Create Store: dist_async
# [08/17/2019 23:38:55 INFO 140385467369280] nvidia-smi took: 0.0251729488373 secs to identify 0 gpus
# [08/17/2019 23:38:55 INFO 140385467369280] Number of GPUs being used: 0
# [08/17/2019 23:38:55 INFO 140385467369280] Setting up with params: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'100', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'10', u'_num_slices': u'1'}
# [08/17/2019 23:38:55 INFO 140385467369280] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [08/17/2019 23:38:55 INFO 140385467369280] Number of GPUs being used: 0
# [08/17/2019 23:38:55 INFO 140385467369280] number of center slices 1
# [08/17/2019 23:38:55 WARNING 140385467369280] Batch size 5000 is bigger than the first batch data. Effective batch size used to initialize is 200
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Max Records Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1566085135.885616, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1566085135.885586}
#
# [2019-08-17 23:38:55.885] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 45, "num_examples": 1, "num_bytes": 85600}
# [2019-08-17 23:38:55.930] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 44, "num_examples": 1, "num_bytes": 85600}
# [08/17/2019 23:38:55 INFO 140385467369280] processed a total of 200 examples
# [08/17/2019 23:38:55 INFO 140385467369280] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Total Batches Seen": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Total Records Seen": {"count": 1, "max": 400, "sum": 400.0, "min": 400}, "Max Records Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1566085135.931331, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1566085135.885865}
#
# [08/17/2019 23:38:55 INFO 140385467369280] #throughput_metric: host=algo-1, train throughput=4384.22879124 records/second
# [08/17/2019 23:38:55 INFO 140385467369280] shrinking 100 centers into 10
# [08/17/2019 23:38:55 INFO 140385467369280] local kmeans attempt #0. Current mean square distance 0.299449
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #1. Current mean square distance 0.322694
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #2. Current mean square distance 0.305503
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #3. Current mean square distance 0.299493
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #4. Current mean square distance 0.303521
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #5. Current mean square distance 0.306142
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #6. Current mean square distance 0.299886
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #7. Current mean square distance 0.307972
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #8. Current mean square distance 0.305669
# [08/17/2019 23:38:56 INFO 140385467369280] local kmeans attempt #9. Current mean square distance 0.299525
# [08/17/2019 23:38:56 INFO 140385467369280] finished shrinking process. Mean Square Distance = 0
# [08/17/2019 23:38:56 INFO 140385467369280] #quality_metric: host=algo-1, train msd <loss>=0.299448698759
# [08/17/2019 23:38:56 INFO 140385467369280] compute all data-center distances: inner product took: 36.2489%, (0.018624 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] collect from kv store took: 14.2550%, (0.007324 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] splitting centers key-value pair took: 13.5195%, (0.006946 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] compute all data-center distances: point norm took: 8.9997%, (0.004624 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] gradient: cluster center took: 7.5871%, (0.003898 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] gradient: one_hot took: 6.7379%, (0.003462 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] batch data loading with context took: 6.5769%, (0.003379 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] predict compute msd took: 3.8632%, (0.001985 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] update state and report convergance took: 0.6325%, (0.000325 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] gradient: cluster size  took: 0.5606%, (0.000288 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] update set-up time took: 0.5355%, (0.000275 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] compute all data-center distances: center norm took: 0.4399%, (0.000226 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] predict minus dist took: 0.0432%, (0.000022 secs)
# [08/17/2019 23:38:56 INFO 140385467369280] TOTAL took: 0.0513782501221
# [08/17/2019 23:38:56 INFO 140385467369280] Number of GPUs being used: 0
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 391.646146774292, "sum": 391.646146774292, "min": 391.646146774292}, "initialize.time": {"count": 1, "max": 42.66691207885742, "sum": 42.66691207885742, "min": 42.66691207885742}, "model.serialize.time": {"count": 1, "max": 0.17690658569335938, "sum": 0.17690658569335938, "min": 0.17690658569335938}, "update.time": {"count": 1, "max": 45.255184173583984, "sum": 45.255184173583984, "min": 45.255184173583984}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 0.2071857452392578, "sum": 0.2071857452392578, "min": 0.2071857452392578}, "_shrink.time": {"count": 1, "max": 389.3117904663086, "sum": 389.3117904663086, "min": 389.3117904663086}}, "EndTime": 1566085136.330112, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1566085135.839771}
#
# [08/17/2019 23:38:56 INFO 140385467369280] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1393.4650421142578, "sum": 1393.4650421142578, "min": 1393.4650421142578}, "setuptime": {"count": 1, "max": 24.595975875854492, "sum": 24.595975875854492, "min": 24.595975875854492}}, "EndTime": 1566085136.330698, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1566085136.33026}
#
# [08/17/2019 23:38:56 INFO 139887317694272] local kmeans attempt #5. Current mean square distance 0.300583
# [08/17/2019 23:38:56 INFO 139887317694272] local kmeans attempt #6. Current mean square distance 0.298211
# [08/17/2019 23:38:56 INFO 139887317694272] local kmeans attempt #7. Current mean square distance 0.311163
# [08/17/2019 23:38:56 INFO 139887317694272] local kmeans attempt #8. Current mean square distance 0.299109
# [08/17/2019 23:38:56 INFO 139887317694272] local kmeans attempt #9. Current mean square distance 0.296317
# [08/17/2019 23:38:56 INFO 139887317694272] finished shrinking process. Mean Square Distance = 0
# [08/17/2019 23:38:56 INFO 139887317694272] #quality_metric: host=algo-2, train msd <loss>=0.295574247837
# [08/17/2019 23:38:56 INFO 139887317694272] compute all data-center distances: inner product took: 39.1627%, (0.022261 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] collect from kv store took: 13.2912%, (0.007555 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] splitting centers key-value pair took: 12.2200%, (0.006946 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] compute all data-center distances: point norm took: 9.2730%, (0.005271 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] batch data loading with context took: 7.5331%, (0.004282 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] gradient: cluster center took: 6.3424%, (0.003605 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] gradient: one_hot took: 6.2278%, (0.003540 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] predict compute msd took: 4.0568%, (0.002306 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] update set-up time took: 0.5050%, (0.000287 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] gradient: cluster size  took: 0.4907%, (0.000279 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] update state and report convergance took: 0.4538%, (0.000258 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] compute all data-center distances: center norm took: 0.4048%, (0.000230 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] predict minus dist took: 0.0386%, (0.000022 secs)
# [08/17/2019 23:38:56 INFO 139887317694272] TOTAL took: 0.0568420886993
# [08/17/2019 23:38:56 INFO 139887317694272] Number of GPUs being used: 0
# [08/17/2019 23:38:56 INFO 139887317694272] No model is serialized on a non-master node
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 287.63890266418457, "sum": 287.63890266418457, "min": 287.63890266418457}, "initialize.time": {"count": 1, "max": 42.9530143737793, "sum": 42.9530143737793, "min": 42.9530143737793}, "model.serialize.time": {"count": 1, "max": 0.08511543273925781, "sum": 0.08511543273925781, "min": 0.08511543273925781}, "update.time": {"count": 1, "max": 50.82106590270996, "sum": 50.82106590270996, "min": 50.82106590270996}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 0.19288063049316406, "sum": 0.19288063049316406, "min": 0.19288063049316406}, "_shrink.time": {"count": 1, "max": 285.48598289489746, "sum": 285.48598289489746, "min": 285.48598289489746}}, "EndTime": 1566085136.15987, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1566085135.773722}
#
# [08/17/2019 23:38:56 INFO 139887317694272] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2579.1399478912354, "sum": 2579.1399478912354, "min": 2579.1399478912354}, "setuptime": {"count": 1, "max": 16.68715476989746, "sum": 16.68715476989746, "min": 16.68715476989746}}, "EndTime": 1566085136.160366, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1566085136.159999}
#
#
# 2019-08-17 23:39:05 Uploading - Uploading generated training model
# 2019-08-17 23:39:05 Completed - Training job completed
# Billable seconds: 97

# %% [markdown]
# # クラスタリングモデルの評価
# まずは学習されたK-Meansモデルを推論エンドポイントへデプロイして、推論(ベクトル表現のグループ化)ができる状態にします。

# %%
kmeans_endpoint = kmeans.deploy(initial_instance_count=1,
                                instance_type='ml.m4.xlarge')
# Out:
# --------------------------------------------------------------------------------------------------!

# %% [markdown]
# 今回は400個の単語がを10個のグループにクラスタリングしました。どのような単語がどのグループに所属するか確認しましょう。

# %%
# 学習用に使ったデータ(10次元ベクトル表現データ)を推論に使い、クラスを得る。
result = kmeans_endpoint.predict(word_vecs32)

clusters = [r.label['closest_cluster'].float32_tensor.values[0] for r in result]
for cluster in range(10):
    words = [word for l, word in zip(clusters, labels) if int(l) == cluster]
    print('クラスタ{}に属する単語は下記となります'.format(cluster))
    print(words)
    print('============================================')
# Out:
# クラスタ0に属する単語は下記となります
# ['体', '状態']
# ============================================
# クラスタ1に属する単語は下記となります
# ['を', 'さ', 'する', '・', '「', 'から', 'な', 'れる', '的', '者', 'へ', '後', 'まで', 'という', '(', ')', 'これ', 'により', '"', 'によって', 'による', '時', '一', '化', '部', '名', '性', '本', '間', 'せ', '行わ', '大', 'その後', 'できる', 'ば', '二', '会', '使用', '数', '当時', '受け', '内', '機', '前', '呼ば', '型', 'つ', 'および', '開発', '次', '：', '三', '行っ', '彼', '中心', '法', 'における', 'たち', ':', '長', '新', 'さらに', '際', '下', '式', '用', '時間', '開始', '発表', '分', '所', '利用', '局', '参加', '全', '側', '必要', '用い', 'に対して', '計画', '社', '行う', '設置', 'にて', 'たり', '持つ', '知ら', '事業', 'せる', '務め', 'なら', '会社', '力', '建設', '各', '委員', '物', 'とともに', 'とき', 'ながら', 'うち', '＝', '最初', 'そして', '設立', '及び', 'the', '中央', '部分', '一つ', 'それぞれ', '販売', '通り', '権', '経', 'と共に', '路線', '自分']
# ============================================
# クラスタ2に属する単語は下記となります
# ['られ', 'ず', 'なかっ', 'られる', 'う', 'き', '場', '結果', '得', 'ん']
# ============================================
# クラスタ3に属する単語は下記となります
# ['に', 'と', 'し', '」', 'なっ', 'あっ', 'なる', 'より', 'なり', 'だっ', 'それ', '同', '研究', '地域', '系', '以下', '形', 'いう', '関係', '車', '一般', '見', '学', '問題', '考え', '変更', '両', '社会', '政府', '戦争', '機関', '担当', '事件', '意味', '女性', '文化', '政治', '情報']
# ============================================
# クラスタ4に属する単語は下記となります
# ['市', '県', '家', '駅', '町', '州', '国', '郡', '線', '元', '区', '出身', '地', '語', 'ら', '鉄道', '氏', '所属', '村', '地方', '道', '川', '北', '位置', '旧', '南', '島', '生まれ', '東', '地区', '子', '現']
# ============================================
# クラスタ5に属する単語は下記となります
# ['年', '（', '）', '月', '日', '1', '2', '-', '3', '4', '5', '6', '10', '7', '8', '9', '12', '11', '20', '15', '30', '16', '18', '13', '14', '19', '17', '21', '25', '24', '23', '22']
# ============================================
# クラスタ6に属する単語は下記となります
# ['人', '第', '日本', '.', 'だ', ',', '軍', '時代', '回', '世界', '戦', '位', '東京', '昭和', '大学', '号', '活動', '学校', '目', 'アメリカ', '/', '初', '万', '約', '代表', '歳', 'm', '世', '年代', '試合', '出場', '賞', 'チーム', '選手', '大会', '0.35463', '0', 'ドイツ', 'フランス', '以上', 'a', '度', '記録', '点', '開催', '優勝', '世紀', '王', 'リーグ', 'シーズン', '級', '明治', '国際', 'イギリス', '都市', '頃', '教育', '期', '種', '大阪', '中国', '卒業', 'km', '獲得', '自身', '代', '高', '攻撃', '年間', '科', 'デビュー', '艦', '場所', '%', '十', '高等']
# ============================================
# クラスタ7に属する単語は下記となります
# ['の', '、', '。', 'は', 'た', 'が', 'で', 'て', 'れ', 'ある', 'いる', 'も', 'こと', 'い', 'として', 'や', 'など', 'この', 'ない', 'ため', 'その', 'よう', 'また', 'あり', 'もの', '中', 'おり', 'か', 'において', '上', '場合', 'なく', 'しかし', '多く', 'について', '他', '存在', '等', 'のみ', 'でき', '可能', 'なお', '一部', '主', '以降', 'だけ', '事', '多い', '同じ', 'ほか', 'これら', '一方', '特に', '影響', 'でも', '当初', '同様', '以外', 'ので']
# ============================================
# クラスタ8に属する単語は下記となります
# ['』', '『', '放送', '作品', '番組', '映画', '発売', '作', '登場', '曲', '音楽', '版', 'シリーズ', '監督', 'テレビ', 'ゲーム', '出演', 'アルバム']
# ============================================
# クラスタ9に属する単語は下記となります
# ['現在', '同年', '平成', '2010', '2009', '2007', '2008', '2011', '2012', '2006', '2013', '2014', '2005', '2000', '2015']
# ============================================

# %% [markdown]
# ## 入力する任意の文字列に対するクラスタリング
# 新しい単語に対してはWord2Vecでベクトル化した上で、K-Meansにてどのグループに所属するかを計算します。

# %%
# 新しい単語を入力します。
input_word = '自動車'
new_word = [input_word]

# Word2Vecの推論エンドポイントへリクエストとして入力しベクトル表現を得る
payload = {"instances" : new_word}
response = bt_endpoint.predict(json.dumps(payload))
new_vec = normalize(np.array(json.loads(response)[0]['vector']).reshape(1, -1), copy=False, return_norm=False).astype('float32')

# K-Meansの推論エンドポイントへベクトル表現を入力し所属するグループを得る
result = kmeans_endpoint.predict(new_vec)

# 同じクラスに所属する単語を表示する
similar_words = [word for l, word in zip(clusters, labels) if int(l) == int(result[0].label['closest_cluster'].float32_tensor.values[0])]
print('入力された文字列は「{}」です'.format(input_word))
print('====類似性の近い単語群は下記です。＝＝＝＝＝＝')
print(similar_words)
# Out:
# 入力された文字列は「自動車」です
# ====類似性の近い単語群は下記です。＝＝＝＝＝＝
# ['を', 'さ', 'する', '・', '「', 'から', 'な', 'れる', '的', '者', 'へ', '後', 'まで', 'という', '(', ')', 'これ', 'により', '"', 'によって', 'による', '時', '一', '化', '部', '名', '性', '本', '間', 'せ', '行わ', '大', 'その後', 'できる', 'ば', '二', '会', '使用', '数', '当時', '受け', '内', '機', '前', '呼ば', '型', 'つ', 'および', '開発', '次', '：', '三', '行っ', '彼', '中心', '法', 'における', 'たち', ':', '長', '新', 'さらに', '際', '下', '式', '用', '時間', '開始', '発表', '分', '所', '利用', '局', '参加', '全', '側', '必要', '用い', 'に対して', '計画', '社', '行う', '設置', 'にて', 'たり', '持つ', '知ら', '事業', 'せる', '務め', 'なら', '会社', '力', '建設', '各', '委員', '物', 'とともに', 'とき', 'ながら', 'うち', '＝', '最初', 'そして', '設立', '及び', 'the', '中央', '部分', '一つ', 'それぞれ', '販売', '通り', '権', '経', 'と共に', '路線', '自分']

# %% [markdown]
# ## 推論エンドポイントの削除
# エンドポイントは起動したままだとコストがかかります。不要な場合は削除します。

# %%
sagemaker.Session().delete_endpoint(bt_endpoint.endpoint)
sagemaker.Session().delete_endpoint(kmeans_endpoint.endpoint)

# %% [markdown]
# ## 参考
# - [機械学習のための特徴量エンジニアリング](https://www.oreilly.co.jp/books/9784873118680/)
#     - 3章テキストデータの取り扱い、4章特徴量スケーリングによる効果
# - [自然言語処理における前処理の種類とその威力](https://qiita.com/Hironsan/items/2466fe0f344115aff177)
